# %%
from IPython import get_ipython
from IPython.display import display
# %%
# !pip install librosa scikit-learn matplotlib numpy soundfile moviepy pillow
# Out:
# Requirement already satisfied: librosa in /usr/local/lib/python3.11/dist-packages (0.11.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.11/dist-packages (0.13.1)
# Requirement already satisfied: moviepy in /usr/local/lib/python3.11/dist-packages (1.0.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (11.2.1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.60.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.15.3)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.5.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: typing_extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (4.14.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.1.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile) (1.17.1)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.11/dist-packages (from moviepy) (4.67.1)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from moviepy) (2.32.3)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.11/dist-packages (from moviepy) (0.1.12)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.11/dist-packages (from moviepy) (2.37.0)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from moviepy) (0.6.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile) (2.22)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa) (4.3.8)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2025.4.26)

# %%
import numpy as np
import librosa
import soundfile as sf
from sklearn.ensemble import RandomForestClassifier
from moviepy.editor import VideoClip, AudioFileClip
from PIL import Image, ImageDraw, ImageFont
import matplotlib.pyplot as plt
import tempfile
import random

# %%
SAMPLE_RATE = 22050

CHORDS = {
    # Major Triads
    "C Major":   ['C', 'E', 'G'],
    "C# Major":  ['C#', 'F', 'G#'],
    "D Major":   ['D', 'F#', 'A'],
    "D# Major":  ['D#', 'G', 'A#'],
    "E Major":   ['E', 'G#', 'B'],
    "F Major":   ['F', 'A', 'C'],
    "F# Major":  ['F#', 'A#', 'C#'],
    "G Major":   ['G', 'B', 'D'],
    "G# Major":  ['G#', 'C', 'D#'],
    "A Major":   ['A', 'C#', 'E'],
    "A# Major":  ['A#', 'D', 'F'],
    "B Major":   ['B', 'D#', 'F#'],

    # Minor Triads
    "C Minor":   ['C', 'D#', 'G'],
    "C# Minor":  ['C#', 'E', 'G#'],
    "D Minor":   ['D', 'F', 'A'],
    "D# Minor":  ['D#', 'F#', 'A#'],
    "E Minor":   ['E', 'G', 'B'],
    "F Minor":   ['F', 'G#', 'C'],
    "F# Minor":  ['F#', 'A', 'C#'],
    "G Minor":   ['G', 'A#', 'D'],
    "G# Minor":  ['G#', 'B', 'D#'],
    "A Minor":   ['A', 'C', 'E'],
    "A# Minor":  ['A#', 'C#', 'F'],
    "B Minor":   ['B', 'D', 'F#']
}

NOTE_FREQ = {
    'C': 261.63, 'C#': 277.18, 'D': 293.66, 'D#': 311.13, 'E': 329.63, 'F': 349.23,
    'F#': 369.99, 'G': 392.00, 'G#': 415.30, 'A': 440.00, 'A#': 466.16, 'B': 493.88
}


def synth_chord(notes, duration=1.0, sr=SAMPLE_RATE, noise_level=0.01):
    t = np.linspace(0, duration, int(sr * duration), False)
    audio = sum(np.sin(2 * np.pi * NOTE_FREQ[note] * t) for note in notes)
    audio /= len(notes)
    fade = np.linspace(1, 0.1, len(audio))
    audio = audio * fade
    # Add some random noise to make it more realistic
    noise = noise_level * np.random.randn(len(audio))
    audio += noise
    return audio.astype(np.float32)

X, y = [], []
for chord_label, notes in CHORDS.items():
    for i in range(50):  # Increased samples per chord
        duration = random.uniform(0.5, 1.5) # Vary duration
        audio = synth_chord(notes, duration=duration)
        fname = f'tmp_{chord_label}_{i}.wav'
        sf.write(fname, audio, SAMPLE_RATE)
        y_audio, sr = librosa.load(fname, sr=SAMPLE_RATE)
        # Use more detailed chroma features
        chroma_stft = librosa.feature.chroma_stft(y=y_audio, sr=sr)
        chroma_cqt = librosa.feature.chroma_cqt(y=y_audio, sr=sr)
        chroma_cens = librosa.feature.chroma_cens(y=y_audio, sr=sr)
        # Combine features
        feat = np.concatenate((np.mean(chroma_stft, axis=1),
                              np.mean(chroma_cqt, axis=1),
                              np.mean(chroma_cens, axis=1)))
        X.append(feat)
        y.append(chord_label)
X = np.array(X)
y = np.array(y)
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=722
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=361
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=914
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=457
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=786
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=393
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=197
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=638
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=319
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=981
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=491
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=570
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=285
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=941
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=471
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=679
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=340
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=576
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=288
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=930
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=465
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=939
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=470
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=235
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=656
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=328
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=515
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=984
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=492
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=992
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=496
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=248
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=707
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=354
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=740
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=370
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=185
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=792
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=396
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=198
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=874
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=437
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=591
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=296
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=720
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=360
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=910
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=455
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=561
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=281
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=597
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=299
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=935
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=468
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=906
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=453
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=579
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=290
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=649
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=325
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=784
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=392
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=942
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=842
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=421
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=211
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=973
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=487
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=525
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=263
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=859
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=430
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=949
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=475
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=832
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=416
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=759
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=380
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=718
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=359
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=602
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=301
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=762
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=381
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=823
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=412
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=556
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=278
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=821
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=411
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=206
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=588
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=294
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=974
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=789
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=395
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=652
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=326
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=757
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=379
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=190
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=532
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=266
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=634
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=317
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=1004
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=502
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=963
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=482
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=827
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=414
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=207
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=958
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=479
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=677
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=339
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=928
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=464
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=232
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=692
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=346
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=866
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=433
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=839
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=420
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=886
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=443
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=222
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=882
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=441
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=944
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=472
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=236
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=748
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=374
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=665
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=333
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=919
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=460
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=230
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=861
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=431
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=922
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=461
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=863
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=432
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=216
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=569
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=954
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=477
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=670
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=335
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=234
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=699
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=350
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=946
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=473
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=237
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=871
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=436
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=985
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=493
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=862
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=777
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=389
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=572
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=286
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=834
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=417
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=603
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=302
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=849
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=425
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=917
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=459
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=733
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=367
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=613
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=307
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=819
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=410
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=547
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=274
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=948
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=474
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=1017
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=509
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=803
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=402
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=201
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=962
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=481
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=241
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=986
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=870
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=435
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=843
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=422
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=1007
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=504
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=742
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=371
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=719
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=921
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=567
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=284
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=238
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=562
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=513
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=218
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=825
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=413
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=723
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=362
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=904
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=452
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=820
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=927
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=571
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=936
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=891
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=446
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=829
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=415
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=686
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=343
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=987
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=494
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=824
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=651
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=582
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=291
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=635
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=318
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=810
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=405
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=977
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=489
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=599
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=300
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=560
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=280
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=245
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=517
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=888
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=444
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=215
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=750
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=375
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=712
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=356
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=178
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=989
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=495
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=846
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=423
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=212
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=709
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=355
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=778
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=695
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=348
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=848
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=424
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=1018
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=796
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=398
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=1016
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=508
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=254
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=711
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=788
#   warnings.warn(
#
# ...
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=793
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=611
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=306
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=880
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=220
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=756
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=704
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=352
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=619
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=310
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=625
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=208
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=553
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=607
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=180
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=787
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=199
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=805
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=403
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=828
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=647
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=527
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=264
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=715
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=358
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=179
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=697
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=1010
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=505
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=998
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=499
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=937
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=239
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=826
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=979
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=830
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=971
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=734
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=774
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=387
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=800
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=926
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=533
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=758
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=578
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=743
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=372
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=516
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=226
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=766
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=982
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=920
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=1000
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=934
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=581
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=596
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=298
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=640
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=320
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=583
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=676
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=592
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=845
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=703
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=219
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=528
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=631
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=612
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=586
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=224
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=923
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=1009
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=628
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=314
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=714
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=666
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=700
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=902
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=451
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=637
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=214
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=916
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=678
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=636
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=997
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=747
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=249
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=744
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=673
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=539
#   warnings.warn(

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X, y)
print("ML chord classifier trained!")
# Out:
# ML chord classifier trained!

# %%
# -- Provide your audio file here:
audio_file = "scientists.wav"  # <---- CHANGE THIS

# Analyze per-beat chords (with ML)
y_song, sr = librosa.load(audio_file, sr=SAMPLE_RATE)
duration = librosa.get_duration(y=y_song, sr=sr)
tempo, beat_frames = librosa.beat.beat_track(y=y_song, sr=sr)
beat_times = librosa.frames_to_time(beat_frames, sr=sr)

# Chord prediction per beat
window_size = int(0.5 * sr)
ml_chord_on_beats = []
for i, beat_time in enumerate(beat_times):
    start_sample = int(max(0, sr * (beat_time - 0.25)))
    end_sample = int(min(len(y_song), sr * (beat_time + 0.25)))
    segment = y_song[start_sample:end_sample]
    if len(segment) == 0:
        ml_chord_on_beats.append(("Unknown", beat_time))
        continue
    # Match feature extraction to training
    chroma_stft_segment = librosa.feature.chroma_stft(y=segment, sr=sr)
    chroma_cqt_segment = librosa.feature.chroma_cqt(y=segment, sr=sr)
    chroma_cens_segment = librosa.feature.chroma_cens(y=segment, sr=sr)
    # Combine features and reshape for prediction
    feat = np.concatenate((np.mean(chroma_stft_segment, axis=1),
                          np.mean(chroma_cqt_segment, axis=1),
                          np.mean(chroma_cens_segment, axis=1))).reshape(1, -1)
    chord_label = clf.predict(feat)[0]
    ml_chord_on_beats.append((chord_label, beat_time))

# Merge repeated chords for better visuals
chord_timeline = []
for i in range(len(beat_times) - 1):
    chord_label = ml_chord_on_beats[i][0]
    start_time = beat_times[i]
    end_time = beat_times[i+1]
    chord_timeline.append((start_time, end_time, chord_label))
merged_chords = []
for segment in chord_timeline:
    if not merged_chords or merged_chords[-1][2] != segment[2]:
        merged_chords.append(segment)
    else:
        merged_chords[-1] = (merged_chords[-1][0], segment[1], merged_chords[-1][2])
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=690
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=345
#   warnings.warn(
#
# WARNING:py.warnings:/usr/local/lib/python3.11/dist-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=1024 is too large for input signal of length=173
#   warnings.warn(

# %%
chord_palette = {
    # Major chords – cheerful, warm, and vivid
    "C Major":   ((255, 255, 0),     'circle'),     # Bright Yellow – Happy, sunny resolution
    "C# Major":  ((255, 0, 255),     'triangle'),   # Magenta – vivid, expressive
    "D Major":   ((0, 255, 0),       'circle'),     # Vibrant Green – Triumphant, fresh
    "D# Major":  ((255, 153, 51),    'hex'),        # Warm Orange – bold, animated
    "E Major":   ((255, 51, 255),    'star'),       # Light Magenta – open and colorful
    "F Major":   ((255, 204, 0),     'rect'),       # Golden Yellow – bright, balanced
    "F# Major":  ((102, 255, 102),   'triangle'),   # Soft Mint – smooth and lush
    "G Major":   ((255, 85, 0),      'circle'),     # Orange-Red – lively, warm
    "G# Major":  ((255, 0, 102),     'star'),       # Hot Pink – playful, vivid
    "A Major":   ((255, 255, 255),   'rect'),       # White – radiant, uplifting (you may change this)
    "A# Major":  ((0, 255, 255),     'triangle'),   # Cyan – energetic and clear
    "B Major":   ((255, 0, 0),       'hex'),        # True Red – confident, intense

    # Minor chords – deep, melancholic, or rich
    "C Minor":   ((51, 0, 153),      'rect'),       # Indigo – calm, reflective
    "C# Minor":  ((75, 0, 130),      'hex'),        # Dark Violet – poetic, obscure
    "D Minor":   ((0, 102, 204),     'triangle'),   # Deep Blue – introspective
    "D# Minor":  ((102, 0, 204),     'star'),       # Midnight Purple – mysterious
    "E Minor":   ((153, 51, 255),    'triangle'),   # Rich Violet – somber but rich
    "F Minor":   ((0, 51, 153),      'hex'),        # Navy Blue – deep, serious
    "F# Minor":  ((0, 0, 204),       'star'),       # Cobalt – cold, immersive
    "G Minor":   ((30, 70, 180),     'rect'),       # Ocean Blue – fragile, thoughtful
    "G# Minor":  ((60, 60, 220),     'triangle'),   # Steel Blue – icy, controlled
    "A Minor":   ((0, 0, 153),       'triangle'),   # Deep Blue – sad or mellow
    "A# Minor":  ((102, 0, 204),     'star'),       # Blue-Violet – dramatic, mysterious
    "B Minor":   ((85, 85, 255),     'hex'),        # Electric Indigo – nostalgic, dreamy

    "Unknown":   ((160, 160, 160),   'circle')      # Mid Gray – undefined
}
W, H = 720, 720


def draw_shape(draw, shape, color, size, center, t_frac):
    x, y = center
    if shape == "circle":
        r = int(size * (0.9 + 0.15*np.sin(2*np.pi*t_frac)))
        draw.ellipse([x - r, y - r, x + r, y + r], fill=color, outline=None)
    elif shape == "rect":
        s = int(size * (0.85 + 0.2*np.cos(2*np.pi*t_frac)))
        draw.rectangle([x - s, y - s, x + s, y + s], fill=color)
    elif shape == "triangle":
        s = int(size * (0.85 + 0.2*np.sin(4*np.pi*t_frac)))
        pts = [(x, y - s), (x - s, y + s), (x + s, y + s)]
        draw.polygon(pts, fill=color)
    elif shape == "hex":
        s = int(size * (0.85 + 0.15*np.cos(4*np.pi*t_frac)))
        angle = np.linspace(0, 2*np.pi, 7)
        pts = [(x + s*np.cos(a), y + s*np.sin(a)) for a in angle]
        draw.polygon(pts, fill=color)
    elif shape == "star":
        s = size
        pts = []
        for i in range(10):
            r = s if i % 2 == 0 else s//2
            theta = np.pi/5 * i + 2*np.pi*t_frac
            pts.append((x + int(r * np.sin(theta)), y - int(r * np.cos(theta))))
        draw.polygon(pts, fill=color)
    # More shapes

def make_frame(t):
    idx = np.searchsorted([bt for _, bt in ml_chord_on_beats], t, side='right') - 1
    chord, bt = ml_chord_on_beats[max(idx, 0)]
    color, shape = chord_palette.get(chord, ((180,180,180), "circle"))
    img = Image.new("RGB", (W, H), (30, 30, 30))
    draw = ImageDraw.Draw(img)
    # Artistic transitions
    next_idx = min(idx+1, len(ml_chord_on_beats)-1)
    bt1 = ml_chord_on_beats[idx][1]
    bt2 = ml_chord_on_beats[next_idx][1] if next_idx != idx else duration
    t_frac = (t - bt1) / max(0.001, (bt2 - bt1))
    next_color = chord_palette.get(ml_chord_on_beats[next_idx][0], ((180,180,180), shape))[0]
    curr_col = tuple(int((1-t_frac)*c1 + t_frac*c2) for c1, c2 in zip(color, next_color))
    draw_shape(draw, shape, curr_col, 170, (W//2, H//2), t_frac)
    try:
        font = ImageFont.truetype("DejaVuSans-Bold.ttf", 54)
    except:
        font = ImageFont.load_default()
    draw.text((W//2-70, H//2+180), chord, font=font, fill=(255,255,255,220))
    return np.array(img)

# %%
video_duration = duration
video = VideoClip(make_frame, duration=video_duration)
audio = AudioFileClip(audio_file).subclip(0, video_duration)
video = video.set_audio(audio)

outpath = tempfile.mktemp(suffix='.mp4')
video.write_videofile(outpath, fps=12, codec="libx264", audio_codec="aac")

# %%
video_duration = duration
video = VideoClip(make_frame, duration=video_duration)
audio = AudioFileClip(audio_file).subclip(0, video_duration)
video = video.set_audio(audio)

outpath = tempfile.mktemp(suffix='.mp4')
video.write_videofile(outpath, fps=12, codec="libx264", audio_codec="aac")
